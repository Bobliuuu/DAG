# %%
# !pip install onediffusion
# Out:
# Collecting onediffusion
#   Downloading onediffusion-0.0.3-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.8 MB/s eta 0:00:00
# Collecting accelerate (from onediffusion)
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.10/dist-packages (from onediffusion) (23.1.0)
# Collecting bentoml[io]>=1.1.2 (from onediffusion)
#   Downloading bentoml-1.1.6-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.6 MB/s eta 0:00:00
# Collecting cattrs>=23.1.0 (from onediffusion)
#   Downloading cattrs-23.1.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.0 MB/s eta 0:00:00
# Collecting diffusers[torch]>=0.19.3 (from onediffusion)
#   Downloading diffusers-0.21.1.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-hub (from onediffusion)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 10.9 MB/s eta 0:00:00
# Collecting inflection (from onediffusion)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting orjson (from onediffusion)
#   Downloading orjson-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from onediffusion) (1.10.12)
# Collecting safetensors (from onediffusion)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: tabulate[widechars]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from onediffusion) (0.9.0)
# Collecting transformers (from onediffusion)
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (3.8.5)
# Collecting circus!=0.17.2,>=0.17.0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading circus-0.18.0-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 19.3 MB/s eta 0:00:00
# Collecting click-option-group (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading click_option_group-0.5.6-py3-none-any.whl (12 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (8.1.7)
# Requirement already satisfied: cloudpickle>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (2.2.1)
# Collecting deepmerge (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading deepmerge-1.1.0-py3-none-any.whl (8.5 kB)
# Collecting fs (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (1.23.5)
# Collecting opentelemetry-api==1.18.0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_api-1.18.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.3 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-aiohttp-client==0.39b0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_instrumentation_aiohttp_client-0.39b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-instrumentation-asgi==0.39b0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_instrumentation_asgi-0.39b0-py3-none-any.whl (13 kB)
# Collecting opentelemetry-instrumentation==0.39b0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_instrumentation-0.39b0-py3-none-any.whl (24 kB)
# Collecting opentelemetry-sdk==1.18.0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_sdk-1.18.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.5 MB/s eta 0:00:00
# Collecting opentelemetry-semantic-conventions==0.39b0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_semantic_conventions-0.39b0-py3-none-any.whl (26 kB)
# Collecting opentelemetry-util-http==0.39b0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading opentelemetry_util_http-0.39b0-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (23.1)
# Collecting pathspec (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Collecting pip-requirements-parser>=31.2.0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading pip_requirements_parser-32.0.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: pip-tools>=6.6.2 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (6.13.0)
# Requirement already satisfied: prometheus-client>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (0.17.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (5.9.5)
# Collecting pynvml<12 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (2.8.2)
# Collecting python-json-logger (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting python-multipart (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (2.31.0)
# Requirement already satisfied: rich>=11.2.0 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (13.5.2)
# Collecting schema (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Collecting simple-di>=0.1.4 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading simple_di-0.1.5-py3-none-any.whl (9.8 kB)
# Collecting starlette>=0.13.5 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading starlette-0.31.1-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 7.9 MB/s eta 0:00:00
# Collecting uvicorn (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.4 MB/s eta 0:00:00
# Collecting watchfiles>=0.15.0 (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.3 MB/s eta 0:00:00
# Collecting deprecated>=1.2.6 (from opentelemetry-api==1.18.0->bentoml[io]>=1.1.2->onediffusion)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata~=6.0.0 (from opentelemetry-api==1.18.0->bentoml[io]>=1.1.2->onediffusion)
#   Downloading importlib_metadata-6.0.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api==1.18.0->bentoml[io]>=1.1.2->onediffusion) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.39b0->bentoml[io]>=1.1.2->onediffusion) (1.15.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.39b0->bentoml[io]>=1.1.2->onediffusion)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk==1.18.0->bentoml[io]>=1.1.2->onediffusion) (4.5.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from cattrs>=23.1.0->onediffusion) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]>=0.19.3->onediffusion) (3.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]>=0.19.3->onediffusion) (2023.6.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]>=0.19.3->onediffusion) (9.4.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]>=0.19.3->onediffusion) (2.0.1+cu118)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->onediffusion) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->onediffusion) (4.66.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from tabulate[widechars]>=0.9.0->onediffusion) (0.2.6)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->onediffusion)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=17.0 in /usr/local/lib/python3.10/dist-packages (from circus!=0.17.2,>=0.17.0->bentoml[io]>=1.1.2->onediffusion) (23.2.1)
# Requirement already satisfied: tornado>=5.0.2 in /usr/local/lib/python3.10/dist-packages (from circus!=0.17.2,>=0.17.0->bentoml[io]>=1.1.2->onediffusion) (6.3.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata~=6.0.0->opentelemetry-api==1.18.0->bentoml[io]>=1.1.2->onediffusion) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.1->bentoml[io]>=1.1.2->onediffusion) (2.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from pip-requirements-parser>=31.2.0->bentoml[io]>=1.1.2->onediffusion) (3.1.1)
# Requirement already satisfied: build in /usr/local/lib/python3.10/dist-packages (from pip-tools>=6.6.2->bentoml[io]>=1.1.2->onediffusion) (1.0.3)
# Requirement already satisfied: pip>=22.2 in /usr/local/lib/python3.10/dist-packages (from pip-tools>=6.6.2->bentoml[io]>=1.1.2->onediffusion) (23.1.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from pip-tools>=6.6.2->bentoml[io]>=1.1.2->onediffusion) (0.41.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.2.0->bentoml[io]>=1.1.2->onediffusion) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.2.0->bentoml[io]>=1.1.2->onediffusion) (2.16.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette>=0.13.5->bentoml[io]>=1.1.2->onediffusion) (3.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]>=0.19.3->onediffusion) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]>=0.19.3->onediffusion) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]>=0.19.3->onediffusion) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->diffusers[torch]>=0.19.3->onediffusion) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->diffusers[torch]>=0.19.3->onediffusion) (16.0.6)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->bentoml[io]>=1.1.2->onediffusion) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->bentoml[io]>=1.1.2->onediffusion) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->bentoml[io]>=1.1.2->onediffusion) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->bentoml[io]>=1.1.2->onediffusion) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->bentoml[io]>=1.1.2->onediffusion) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->bentoml[io]>=1.1.2->onediffusion) (1.3.1)
# Collecting filetype (from bentoml[io]>=1.1.2->onediffusion)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (1.5.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from bentoml[io]>=1.1.2->onediffusion) (9.0.0)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.10/dist-packages (from fs->bentoml[io]>=1.1.2->onediffusion) (1.4.4)
# Requirement already satisfied: six~=1.10 in /usr/local/lib/python3.10/dist-packages (from fs->bentoml[io]>=1.1.2->onediffusion) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bentoml[io]>=1.1.2->onediffusion) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bentoml[io]>=1.1.2->onediffusion) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bentoml[io]>=1.1.2->onediffusion) (2023.7.22)
# Requirement already satisfied: contextlib2>=0.5.5 in /usr/local/lib/python3.10/dist-packages (from schema->bentoml[io]>=1.1.2->onediffusion) (21.6.0)
# Collecting h11>=0.8 (from uvicorn->bentoml[io]>=1.1.2->onediffusion)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.13.5->bentoml[io]>=1.1.2->onediffusion) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->bentoml[io]>=1.1.2->onediffusion) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->bentoml[io]>=1.1.2->onediffusion) (2023.3.post1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build->pip-tools>=6.6.2->bentoml[io]>=1.1.2->onediffusion) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build->pip-tools>=6.6.2->bentoml[io]>=1.1.2->onediffusion) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->diffusers[torch]>=0.19.3->onediffusion) (1.3.0)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.21.1-py3-none-any.whl size=1486516 sha256=fac8aec5ac35555b9cbce8543e93c3669d1e0b7cadb2fa1f9bdbe256ac6ce8a0
#   Stored in directory: /root/.cache/pip/wheels/a8/52/ec/901d7f3e1128bc56ea4365e9d3a157c1088e5450f4e8f7b202
# Successfully built diffusers
# Installing collected packages: tokenizers, safetensors, filetype, deepmerge, simple-di, schema, python-multipart, python-json-logger, pynvml, pip-requirements-parser, pathspec, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, inflection, importlib-metadata, h11, fs, deprecated, click-option-group, circus, cattrs, asgiref, watchfiles, uvicorn, starlette, opentelemetry-api, huggingface-hub, transformers, opentelemetry-sdk, opentelemetry-instrumentation, diffusers, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-aiohttp-client, bentoml, accelerate, onediffusion
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.8.0
#     Uninstalling importlib-metadata-6.8.0:
#       Successfully uninstalled importlib-metadata-6.8.0
# Successfully installed accelerate-0.23.0 asgiref-3.7.2 bentoml-1.1.6 cattrs-23.1.2 circus-0.18.0 click-option-group-0.5.6 deepmerge-1.1.0 deprecated-1.2.14 diffusers-0.21.1 filetype-1.2.0 fs-2.4.16 h11-0.14.0 huggingface-hub-0.17.1 importlib-metadata-6.0.1 inflection-0.5.1 onediffusion-0.0.3 opentelemetry-api-1.18.0 opentelemetry-instrumentation-0.39b0 opentelemetry-instrumentation-aiohttp-client-0.39b0 opentelemetry-instrumentation-asgi-0.39b0 opentelemetry-sdk-1.18.0 opentelemetry-semantic-conventions-0.39b0 opentelemetry-util-http-0.39b0 orjson-3.9.7 pathspec-0.11.2 pip-requirements-parser-32.0.1 pynvml-11.5.0 python-json-logger-2.0.7 python-multipart-0.0.6 safetensors-0.3.3 schema-0.7.5 simple-di-0.1.5 starlette-0.31.1 tokenizers-0.13.3 transformers-4.33.2 uvicorn-0.23.2 watchfiles-0.20.0

# %%
# !onediffusion start stable-diffusion-xl
# Out:
# /usr/local/lib/python3.10/dist-packages/onediffusion/_configuration.py:832: RuntimeWarning: The empty option group "StableDiffusionConfig options" was found (line 832) for "model_start". The group will not be added.
#   return cog.optgroup.group(f"{cls.__name__} options")(f)
# /usr/local/lib/python3.10/dist-packages/onediffusion/_configuration.py:832: RuntimeWarning: The empty option group "StableDiffusionXLConfig options" was found (line 832) for "model_start". The group will not be added.
#   return cog.optgroup.group(f"{cls.__name__} options")(f)
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-09-17 09:09:14.113465: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# pt-sdxl-stabilityai--stable-diffusion-xl-base-1.0 not in model store, try to import
# Using the default model signature for diffusers ({'__call__': {'batchable': False}}) for model "pt-sdxl-stabilityai--stable-diffusion-xl-base-1.0".
# Downloading (…)ain/model_index.json: 100% 609/609 [00:00<00:00, 2.94MB/s]
# Fetching 19 files:   0% 0/19 [00:00<?, ?it/s]
# Downloading model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
# Downloading (…)_encoder/config.json: 100% 565/565 [00:00<00:00, 2.28MB/s]
#
#
# Downloading model.safetensors:   0% 0.00/2.78G [00:00<?, ?B/s]
# Downloading model.safetensors:   2% 10.5M/492M [00:00<00:08, 58.6MB/s]
#
# Downloading model.safetensors:   0% 10.5M/2.78G [00:00<00:46, 59.6MB/s]
#
#
# Downloading (…)cheduler_config.json: 100% 479/479 [00:00<00:00, 1.54MB/s]
# Fetching 19 files:  11% 2/19 [00:01<00:12,  1.38it/s]
#
#
# Downloading (…)ncoder_2/config.json: 100% 575/575 [00:00<00:00, 2.30MB/s]
#
# Downloading model.safetensors:   4% 21.0M/492M [00:00<00:08, 58.6MB/s]
#
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 1.57MB/s]
#
#
#
# Downloading (…)okenizer_config.json: 100% 737/737 [00:00<00:00, 3.12MB/s]
#
#
# Downloading model.safetensors:   1% 21.0M/2.78G [00:00<00:55, 50.0MB/s]
#
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading model.safetensors:   6% 31.5M/492M [00:00<00:07, 62.2MB/s]
#
# Downloading model.safetensors:   1% 31.5M/2.78G [00:00<00:49, 55.5MB/s]
# Downloading model.safetensors:   9% 41.9M/492M [00:00<00:06, 65.9MB/s]
#
#
#
# Downloading (…)tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# Downloading model.safetensors:   2% 41.9M/2.78G [00:00<00:49, 55.0MB/s]
# Downloading model.safetensors:  11% 52.4M/492M [00:00<00:06, 65.8MB/s]
#
# Downloading model.safetensors:   2% 52.4M/2.78G [00:00<00:47, 57.1MB/s]
# Downloading model.safetensors:  13% 62.9M/492M [00:00<00:06, 63.2MB/s]
#
# Downloading model.safetensors:   2% 62.9M/2.78G [00:01<00:47, 57.0MB/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100% 725/725 [00:00<00:00, 1.63MB/s]
#
# Downloading model.safetensors:  15% 73.4M/492M [00:01<00:06, 63.2MB/s]
#
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 1.40MB/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100% 460/460 [00:00<00:00, 1.44MB/s]
#
#
#
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 950kB/s]
#
# Downloading model.safetensors:  17% 83.9M/492M [00:01<00:06, 62.9MB/s]
#
# Downloading model.safetensors:   3% 73.4M/2.78G [00:01<00:50, 53.3MB/s]
#
#
# Downloading (…)kenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# Downloading (…)kenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
# Downloading (…)kenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 32.1MB/s]
#
#
# Downloading model.safetensors:   3% 83.9M/2.78G [00:01<00:48, 56.0MB/s]
#
#
#
# Downloading (…)76f/unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 5.05MB/s]
#
#
#
#
# Downloading (…)d76f/vae/config.json: 100% 642/642 [00:00<00:00, 1.74MB/s]
#
#
# Downloading model.safetensors:   3% 94.4M/2.78G [00:01<00:46, 57.2MB/s]
# Downloading model.safetensors:  21% 105M/492M [00:01<00:06, 56.9MB/s]
# Downloading model.safetensors:  23% 115M/492M [00:01<00:06, 56.4MB/s]
#
# Downloading model.safetensors:   4% 105M/2.78G [00:01<00:53, 50.1MB/s]
# Downloading model.safetensors:  26% 126M/492M [00:02<00:06, 54.5MB/s]
#
#
# Downloading (…)kenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 1.40MB/s]
#
#
# Downloading model.safetensors:   4% 115M/2.78G [00:02<00:54, 49.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/10.3G [00:00<?, ?B/s]
# Downloading model.safetensors:  28% 136M/492M [00:02<00:06, 55.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# Downloading model.safetensors:   5% 126M/2.78G [00:02<00:54, 48.6MB/s]
# Downloading model.safetensors:  30% 147M/492M [00:02<00:06, 55.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 10.5M/10.3G [00:00<03:18, 51.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3% 10.5M/335M [00:00<00:06, 47.8MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# Downloading model.safetensors:   5% 136M/2.78G [00:02<00:54, 48.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 21.0M/10.3G [00:00<03:04, 55.6MB/s]
# Downloading model.safetensors:  32% 157M/492M [00:02<00:06, 50.6MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:   3% 10.5M/335M [00:00<00:06, 53.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:11, 27.7MB/s]
#
# Downloading model.safetensors:   5% 147M/2.78G [00:03<01:10, 37.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 31.5M/10.3G [00:00<04:46, 35.7MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:08, 36.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 41.9M/10.3G [00:00<03:55, 43.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9% 31.5M/335M [00:00<00:08, 34.8MB/s]
#
# Downloading model.safetensors:   6% 157M/2.78G [00:03<01:07, 38.6MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:   9% 31.5M/335M [00:00<00:06, 46.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:01<00:06, 43.4MB/s]
# Downloading model.safetensors:  34% 168M/492M [00:03<00:10, 30.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 52.4M/10.3G [00:01<04:04, 41.7MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:00<00:06, 48.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  16% 52.4M/335M [00:01<00:06, 45.6MB/s]
# Downloading model.safetensors:  36% 178M/492M [00:03<00:09, 34.4MB/s]
#
# Downloading model.safetensors:   6% 168M/2.78G [00:03<01:11, 36.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 62.9M/10.3G [00:01<03:47, 44.9MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  16% 52.4M/335M [00:01<00:05, 48.0MB/s]
# Downloading model.safetensors:  38% 189M/492M [00:03<00:08, 37.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:01<00:05, 45.3MB/s]
#
# Downloading model.safetensors:   6% 178M/2.78G [00:03<01:08, 38.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:01<00:05, 50.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 73.4M/10.3G [00:01<03:44, 45.3MB/s]
# Downloading model.safetensors:  40% 199M/492M [00:04<00:07, 41.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  22% 73.4M/335M [00:01<00:05, 47.3MB/s]
#
# Downloading model.safetensors:   7% 189M/2.78G [00:04<01:01, 42.4MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  22% 73.4M/335M [00:01<00:05, 51.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 83.9M/10.3G [00:01<03:35, 47.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:01<00:04, 51.8MB/s]
# Downloading model.safetensors:  43% 210M/492M [00:04<00:06, 45.1MB/s]
#
# Downloading model.safetensors:   7% 199M/2.78G [00:04<00:54, 47.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 94.4M/10.3G [00:02<03:16, 51.8MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:01<00:04, 54.1MB/s]
# Downloading model.safetensors:  45% 220M/492M [00:04<00:05, 50.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  28% 94.4M/335M [00:02<00:04, 52.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 105M/10.3G [00:02<03:08, 53.8MB/s]
#
# Downloading model.safetensors:   8% 210M/2.78G [00:04<00:56, 45.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  28% 94.4M/335M [00:01<00:04, 55.2MB/s]
# Downloading model.safetensors:  47% 231M/492M [00:04<00:04, 53.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  31% 105M/335M [00:02<00:04, 53.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  34% 115M/335M [00:02<00:03, 61.1MB/s]
#
# Downloading model.safetensors:   8% 220M/2.78G [00:04<00:56, 44.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 115M/10.3G [00:02<03:57, 42.7MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  31% 105M/335M [00:02<00:05, 42.9MB/s]
#
# Downloading model.safetensors:   8% 231M/2.78G [00:04<00:51, 49.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:02<00:03, 59.0MB/s]
# Downloading model.safetensors:  49% 241M/492M [00:04<00:06, 41.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 126M/10.3G [00:03<05:01, 33.7MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  34% 115M/335M [00:02<00:06, 33.5MB/s]
#
# Downloading model.safetensors:   9% 241M/2.78G [00:05<01:08, 36.8MB/s]
# Downloading model.safetensors:  51% 252M/492M [00:05<00:07, 32.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:03<00:05, 34.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 136M/10.3G [00:03<04:40, 36.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:02<00:05, 35.8MB/s]
#
# Downloading model.safetensors:   9% 252M/2.78G [00:05<01:03, 40.0MB/s]
# Downloading model.safetensors:  53% 262M/492M [00:05<00:06, 37.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:03<00:04, 38.3MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:03<00:04, 42.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 147M/10.3G [00:03<04:29, 37.6MB/s]
# Downloading model.safetensors:  55% 273M/492M [00:05<00:05, 39.8MB/s]
#
# Downloading model.safetensors:   9% 262M/2.78G [00:05<01:02, 40.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:03<00:04, 40.6MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:03<00:04, 44.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 157M/10.3G [00:03<04:05, 41.2MB/s]
# Downloading model.safetensors:  58% 283M/492M [00:06<00:04, 43.0MB/s]
#
# Downloading model.safetensors:  10% 273M/2.78G [00:06<01:01, 40.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:03<00:03, 43.7MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:03<00:03, 45.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 168M/10.3G [00:03<03:50, 43.8MB/s]
# Downloading model.safetensors:  60% 294M/492M [00:06<00:04, 43.3MB/s]
#
# Downloading model.safetensors:  10% 283M/2.78G [00:06<00:58, 42.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:03<00:03, 46.2MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:03<00:03, 47.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 178M/10.3G [00:04<03:47, 44.3MB/s]
# Downloading model.safetensors:  62% 304M/492M [00:06<00:04, 46.1MB/s]
#
# Downloading model.safetensors:  11% 294M/2.78G [00:06<00:57, 43.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:04<00:03, 46.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:03<00:03, 48.5MB/s]
# Downloading model.safetensors:  64% 315M/492M [00:06<00:03, 46.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:04<00:02, 51.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 189M/10.3G [00:04<03:52, 43.4MB/s]
#
# Downloading model.safetensors:  11% 304M/2.78G [00:06<00:54, 45.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:04<00:03, 48.2MB/s]
#
# Downloading model.safetensors:  11% 315M/2.78G [00:06<00:50, 49.0MB/s]
# Downloading model.safetensors:  66% 325M/492M [00:06<00:03, 45.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  63% 210M/335M [00:04<00:02, 49.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 199M/10.3G [00:04<03:47, 44.2MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:04<00:02, 46.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 210M/10.3G [00:04<03:27, 48.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  66% 220M/335M [00:04<00:02, 52.6MB/s]
#
# Downloading model.safetensors:  12% 325M/2.78G [00:07<00:53, 46.1MB/s]
# Downloading model.safetensors:  68% 336M/492M [00:07<00:03, 43.6MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  63% 210M/335M [00:04<00:02, 50.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  69% 231M/335M [00:04<00:01, 54.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 220M/10.3G [00:05<03:30, 47.7MB/s]
# Downloading model.safetensors:  70% 346M/492M [00:07<00:03, 47.5MB/s]
#
# Downloading model.safetensors:  12% 336M/2.78G [00:07<00:54, 45.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  66% 220M/335M [00:04<00:02, 48.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:05<00:01, 56.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 231M/10.3G [00:05<03:28, 48.1MB/s]
# Downloading model.safetensors:  72% 357M/492M [00:07<00:02, 47.2MB/s]
#
# Downloading model.safetensors:  12% 346M/2.78G [00:07<00:50, 48.5MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  69% 231M/335M [00:05<00:02, 48.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:05<00:01, 54.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 241M/10.3G [00:05<03:24, 49.1MB/s]
# Downloading model.safetensors:  75% 367M/492M [00:07<00:02, 47.9MB/s]
#
# Downloading model.safetensors:  13% 357M/2.78G [00:07<00:49, 48.9MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:05<00:01, 49.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  78% 262M/335M [00:05<00:01, 50.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 252M/10.3G [00:05<03:19, 50.3MB/s]
#
# Downloading model.safetensors:  13% 367M/2.78G [00:07<00:48, 49.4MB/s]
# Downloading model.safetensors:  77% 377M/492M [00:08<00:02, 44.6MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:05<00:01, 49.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:05<00:01, 49.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 262M/10.3G [00:05<03:13, 51.7MB/s]
#
# Downloading model.safetensors:  14% 377M/2.78G [00:08<00:45, 52.4MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  78% 262M/335M [00:05<00:01, 50.3MB/s]
# Downloading model.safetensors:  79% 388M/492M [00:08<00:02, 46.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  85% 283M/335M [00:05<00:01, 50.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 273M/10.3G [00:06<03:12, 51.8MB/s]
#
# Downloading model.safetensors:  14% 388M/2.78G [00:08<00:46, 51.4MB/s]
# Downloading model.safetensors:  81% 398M/492M [00:08<00:01, 49.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:06<00:00, 52.8MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:05<00:01, 46.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 283M/10.3G [00:06<03:12, 51.9MB/s]
#
# Downloading model.safetensors:  14% 398M/2.78G [00:08<00:46, 51.1MB/s]
# Downloading model.safetensors:  83% 409M/492M [00:08<00:01, 47.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 294M/10.3G [00:06<03:04, 54.1MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  85% 283M/335M [00:06<00:01, 47.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:06<00:00, 49.4MB/s]
#
# Downloading model.safetensors:  15% 409M/2.78G [00:08<00:44, 53.0MB/s]
# Downloading model.safetensors:  85% 419M/492M [00:08<00:01, 50.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 304M/10.3G [00:06<03:15, 51.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  94% 315M/335M [00:06<00:00, 49.8MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:06<00:00, 47.6MB/s]
#
# Downloading model.safetensors:  15% 419M/2.78G [00:09<00:49, 47.5MB/s]
# Downloading model.safetensors:  87% 430M/492M [00:09<00:01, 50.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 315M/10.3G [00:06<03:08, 52.8MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:06<00:00, 50.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:06<00:00, 50.8MB/s]
#
# Downloading model.safetensors:  15% 430M/2.78G [00:09<00:47, 49.2MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  94% 315M/335M [00:06<00:00, 56.0MB/s]
# Downloading model.safetensors:  89% 440M/492M [00:09<00:01, 48.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:06<00:00, 53.9MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:07<00:00, 47.6MB/s]
#
#
# Downloading model.safetensors:  16% 440M/2.78G [00:09<00:45, 51.8MB/s]
# Downloading model.safetensors:  92% 451M/492M [00:09<00:00, 54.7MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:06<00:00, 57.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 336M/10.3G [00:07<02:56, 56.3MB/s]
#
# Downloading model.safetensors:  16% 451M/2.78G [00:09<00:39, 58.4MB/s]
# Downloading model.safetensors:  94% 461M/492M [00:09<00:00, 60.8MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:06<00:00, 47.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3% 357M/10.3G [00:07<02:18, 71.5MB/s]
#
# Downloading model.safetensors:  17% 461M/2.78G [00:09<00:36, 63.0MB/s]
# Downloading model.safetensors:  96% 472M/492M [00:09<00:00, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 377M/10.3G [00:07<02:05, 79.0MB/s]
#
# Downloading model.safetensors:  17% 482M/2.78G [00:09<00:32, 70.6MB/s]
# Downloading model.safetensors:  98% 482M/492M [00:09<00:00, 53.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 388M/10.3G [00:07<02:10, 75.9MB/s]
#
# Downloading model.safetensors:  18% 493M/2.78G [00:10<00:47, 48.0MB/s]
# Downloading model.safetensors: 100% 492M/492M [00:10<00:00, 38.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 398M/10.3G [00:08<03:15, 50.5MB/s]
#
# Downloading model.safetensors: 100% 492M/492M [00:10<00:00, 46.9MB/s]
# Fetching 19 files:  21% 4/19 [00:11<00:49,  3.31s/it]
#
#
# Downloading (…)ch_model.safetensors:   4% 409M/10.3G [00:08<02:58, 55.4MB/s]
#
# Downloading model.safetensors:  19% 524M/2.78G [00:10<00:37, 60.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 430M/10.3G [00:08<02:28, 66.5MB/s]
#
# Downloading model.safetensors:  19% 535M/2.78G [00:10<00:38, 58.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 440M/10.3G [00:08<02:28, 66.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 451M/10.3G [00:08<02:27, 66.4MB/s]
#
# Downloading model.safetensors:  20% 545M/2.78G [00:11<00:41, 54.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 461M/10.3G [00:09<02:37, 62.4MB/s]
#
# Downloading model.safetensors:  20% 556M/2.78G [00:11<00:41, 54.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 472M/10.3G [00:09<02:43, 60.0MB/s]
#
# Downloading model.safetensors:  20% 566M/2.78G [00:11<00:40, 54.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 482M/10.3G [00:09<02:42, 60.2MB/s]
#
# Downloading model.safetensors:  21% 577M/2.78G [00:11<00:40, 54.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 493M/10.3G [00:09<02:34, 63.3MB/s]
#
# Downloading model.safetensors:  21% 587M/2.78G [00:11<00:40, 54.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 503M/10.3G [00:09<02:27, 66.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 514M/10.3G [00:09<02:21, 68.8MB/s]
#
# Downloading model.safetensors:  22% 598M/2.78G [00:12<00:38, 56.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 524M/10.3G [00:09<02:17, 71.1MB/s]
#
# Downloading model.safetensors:  22% 608M/2.78G [00:12<00:37, 58.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 535M/10.3G [00:10<02:19, 69.6MB/s]
#
# Downloading model.safetensors:  22% 619M/2.78G [00:12<00:36, 59.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 545M/10.3G [00:10<02:20, 69.4MB/s]
#
# Downloading model.safetensors:  23% 629M/2.78G [00:12<00:36, 58.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 556M/10.3G [00:10<02:19, 69.7MB/s]
#
# Downloading model.safetensors:  23% 640M/2.78G [00:12<00:35, 59.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 566M/10.3G [00:10<02:20, 68.9MB/s]
#
# Downloading model.safetensors:  23% 650M/2.78G [00:12<00:34, 62.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 577M/10.3G [00:10<02:21, 68.6MB/s]
#
# Downloading model.safetensors:  24% 661M/2.78G [00:13<00:32, 64.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 587M/10.3G [00:10<02:19, 69.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 598M/10.3G [00:11<02:22, 67.9MB/s]
#
# Downloading model.safetensors:  24% 671M/2.78G [00:13<00:36, 58.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 608M/10.3G [00:11<02:20, 69.0MB/s]
#
# Downloading model.safetensors:  25% 682M/2.78G [00:13<00:34, 61.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 619M/10.3G [00:11<02:15, 71.1MB/s]
#
# Downloading model.safetensors:  25% 692M/2.78G [00:13<00:35, 59.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 629M/10.3G [00:11<02:20, 68.7MB/s]
#
# Downloading model.safetensors:  25% 703M/2.78G [00:13<00:35, 58.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 640M/10.3G [00:11<02:20, 68.5MB/s]
#
# Downloading model.safetensors:  26% 713M/2.78G [00:14<00:32, 63.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 650M/10.3G [00:11<02:18, 69.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 661M/10.3G [00:11<02:15, 70.8MB/s]
#
# Downloading model.safetensors:  26% 724M/2.78G [00:14<00:36, 56.8MB/s]
#
# Downloading model.safetensors:  26% 734M/2.78G [00:14<00:34, 59.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 671M/10.3G [00:12<02:33, 62.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 682M/10.3G [00:12<02:22, 67.1MB/s]
#
# Downloading model.safetensors:  27% 744M/2.78G [00:14<00:35, 57.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 692M/10.3G [00:12<02:22, 67.2MB/s]
#
# Downloading model.safetensors:  27% 755M/2.78G [00:14<00:37, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 703M/10.3G [00:12<02:21, 67.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 713M/10.3G [00:12<02:23, 66.4MB/s]
#
# Downloading model.safetensors:  28% 765M/2.78G [00:15<00:40, 49.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 724M/10.3G [00:12<02:30, 63.6MB/s]
#
# Downloading model.safetensors:  28% 776M/2.78G [00:15<00:41, 48.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 734M/10.3G [00:13<02:27, 64.7MB/s]
#
# Downloading model.safetensors:  28% 786M/2.78G [00:15<00:40, 48.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 744M/10.3G [00:13<02:22, 66.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 755M/10.3G [00:13<02:22, 67.0MB/s]
#
# Downloading model.safetensors:  29% 797M/2.78G [00:15<00:39, 50.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 765M/10.3G [00:13<02:24, 66.0MB/s]
#
# Downloading model.safetensors:  29% 807M/2.78G [00:15<00:37, 53.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 776M/10.3G [00:13<02:21, 66.9MB/s]
#
# Downloading model.safetensors:  29% 818M/2.78G [00:16<00:36, 53.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 786M/10.3G [00:13<02:28, 63.8MB/s]
#
# Downloading model.safetensors:  30% 828M/2.78G [00:16<00:36, 53.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 797M/10.3G [00:14<02:24, 65.6MB/s]
#
# Downloading model.safetensors:  30% 839M/2.78G [00:16<00:36, 53.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 807M/10.3G [00:14<02:28, 63.8MB/s]
#
# Downloading model.safetensors:  31% 849M/2.78G [00:16<00:36, 53.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 818M/10.3G [00:14<02:29, 63.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 828M/10.3G [00:14<02:28, 63.5MB/s]
#
# Downloading model.safetensors:  31% 860M/2.78G [00:16<00:35, 53.8MB/s]
#
# Downloading model.safetensors:  31% 870M/2.78G [00:17<00:34, 55.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 839M/10.3G [00:14<02:37, 60.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 849M/10.3G [00:14<02:34, 61.0MB/s]
#
# Downloading model.safetensors:  32% 881M/2.78G [00:17<00:34, 55.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 860M/10.3G [00:15<02:31, 62.1MB/s]
#
# Downloading model.safetensors:  32% 891M/2.78G [00:17<00:32, 58.6MB/s]
#
# Downloading model.safetensors:  32% 902M/2.78G [00:17<00:30, 62.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 870M/10.3G [00:15<02:30, 62.4MB/s]
#
# Downloading model.safetensors:  33% 912M/2.78G [00:17<00:31, 59.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 881M/10.3G [00:15<02:33, 61.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 891M/10.3G [00:15<02:32, 61.4MB/s]
#
# Downloading model.safetensors:  33% 923M/2.78G [00:17<00:31, 59.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 902M/10.3G [00:15<02:38, 59.1MB/s]
#
# Downloading model.safetensors:  34% 933M/2.78G [00:18<00:32, 57.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 912M/10.3G [00:18<12:27, 12.5MB/s]
#
# Downloading model.safetensors:  34% 944M/2.78G [00:20<02:27, 12.5MB/s]
#
# Downloading model.safetensors:  35% 965M/2.78G [00:20<01:23, 21.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 933M/10.3G [00:18<07:15, 21.4MB/s]
#
# Downloading model.safetensors:  35% 975M/2.78G [00:20<01:09, 26.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 944M/10.3G [00:18<05:59, 25.9MB/s]
#
# Downloading model.safetensors:  35% 986M/2.78G [00:20<01:01, 29.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 954M/10.3G [00:18<05:18, 29.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 965M/10.3G [00:18<04:29, 34.5MB/s]
#
# Downloading model.safetensors:  36% 996M/2.78G [00:21<00:52, 34.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 975M/10.3G [00:19<04:04, 38.0MB/s]
#
# Downloading model.safetensors:  36% 1.01G/2.78G [00:21<00:47, 37.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 986M/10.3G [00:19<03:32, 43.7MB/s]
#
# Downloading model.safetensors:  37% 1.02G/2.78G [00:21<00:42, 41.5MB/s]
#
# Downloading model.safetensors:  37% 1.03G/2.78G [00:21<00:38, 45.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 996M/10.3G [00:19<03:31, 43.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.01G/10.3G [00:19<03:05, 50.0MB/s]
#
# Downloading model.safetensors:  37% 1.04G/2.78G [00:21<00:35, 49.0MB/s]
#
# Downloading model.safetensors:  38% 1.05G/2.78G [00:22<00:32, 52.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.02G/10.3G [00:19<03:00, 51.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.03G/10.3G [00:19<02:41, 57.1MB/s]
#
# Downloading model.safetensors:  38% 1.06G/2.78G [00:22<00:33, 51.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.04G/10.3G [00:20<02:32, 60.4MB/s]
#
# Downloading model.safetensors:  38% 1.07G/2.78G [00:22<00:30, 56.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.05G/10.3G [00:20<02:20, 65.6MB/s]
#
# Downloading model.safetensors:  39% 1.08G/2.78G [00:22<00:28, 58.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.06G/10.3G [00:20<02:17, 67.2MB/s]
#
# Downloading model.safetensors:  39% 1.09G/2.78G [00:22<00:27, 61.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 1.07G/10.3G [00:20<02:13, 69.1MB/s]
#
# Downloading model.safetensors:  40% 1.10G/2.78G [00:23<00:32, 51.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.08G/10.3G [00:20<02:52, 53.4MB/s]
#
# Downloading model.safetensors:  40% 1.11G/2.78G [00:23<00:30, 54.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.10G/10.3G [00:20<02:05, 73.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.11G/10.3G [00:21<02:07, 71.6MB/s]
#
# Downloading model.safetensors:  40% 1.12G/2.78G [00:23<00:31, 53.1MB/s]
#
# Downloading model.safetensors:  41% 1.13G/2.78G [00:23<00:28, 57.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.12G/10.3G [00:21<02:14, 67.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.13G/10.3G [00:21<02:15, 67.5MB/s]
#
# Downloading model.safetensors:  41% 1.14G/2.78G [00:23<00:28, 57.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.14G/10.3G [00:22<05:49, 26.2MB/s]
#
# Downloading model.safetensors:  42% 1.15G/2.78G [00:25<01:34, 17.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.15G/10.3G [00:23<07:00, 21.7MB/s]
#
# Downloading model.safetensors:  42% 1.16G/2.78G [00:25<01:11, 22.6MB/s]
#
# Downloading model.safetensors:  43% 1.18G/2.78G [00:25<00:46, 34.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 1.17G/10.3G [00:23<04:47, 31.6MB/s]
#
# Downloading model.safetensors:  43% 1.20G/2.78G [00:25<00:40, 39.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.18G/10.3G [00:23<04:09, 36.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.20G/10.3G [00:23<03:47, 39.9MB/s]
#
# Downloading model.safetensors:  43% 1.21G/2.78G [00:26<00:39, 40.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.21G/10.3G [00:24<03:30, 43.1MB/s]
#
# Downloading model.safetensors:  44% 1.22G/2.78G [00:26<00:36, 43.2MB/s]
#
# Downloading model.safetensors:  44% 1.23G/2.78G [00:26<00:33, 46.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.22G/10.3G [00:24<03:18, 45.6MB/s]
#
# Downloading model.safetensors:  45% 1.24G/2.78G [00:26<00:31, 49.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.23G/10.3G [00:24<03:08, 47.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.24G/10.3G [00:24<02:58, 50.7MB/s]
#
# Downloading model.safetensors:  45% 1.25G/2.78G [00:26<00:30, 49.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.25G/10.3G [00:24<02:38, 56.9MB/s]
#
# Downloading model.safetensors:  45% 1.26G/2.78G [00:27<00:29, 50.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.26G/10.3G [00:24<02:37, 57.2MB/s]
#
# Downloading model.safetensors:  46% 1.27G/2.78G [00:27<00:28, 52.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.27G/10.3G [00:25<02:31, 59.4MB/s]
#
# Downloading model.safetensors:  46% 1.28G/2.78G [00:27<00:30, 49.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 1.28G/10.3G [00:25<02:36, 57.4MB/s]
#
# Downloading model.safetensors:  46% 1.29G/2.78G [00:27<00:28, 52.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.29G/10.3G [00:25<02:32, 58.8MB/s]
#
# Downloading model.safetensors:  47% 1.30G/2.78G [00:27<00:25, 57.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.30G/10.3G [00:25<02:26, 61.0MB/s]
#
# Downloading model.safetensors:  47% 1.31G/2.78G [00:27<00:25, 58.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.31G/10.3G [00:25<02:30, 59.4MB/s]
#
# Downloading model.safetensors:  48% 1.32G/2.78G [00:28<00:25, 57.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.32G/10.3G [00:26<03:44, 39.9MB/s]
#
# Downloading model.safetensors:  48% 1.33G/2.78G [00:28<00:35, 40.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.33G/10.3G [00:26<03:55, 38.0MB/s]
#
# Downloading model.safetensors:  48% 1.34G/2.78G [00:28<00:34, 41.9MB/s]
#
# Downloading model.safetensors:  49% 1.35G/2.78G [00:29<00:34, 41.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.34G/10.3G [00:26<03:57, 37.7MB/s]
#
# Downloading model.safetensors:  49% 1.36G/2.78G [00:29<00:34, 40.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.35G/10.3G [00:27<04:13, 35.2MB/s]
#
# Downloading model.safetensors:  49% 1.37G/2.78G [00:29<00:33, 42.2MB/s]
#
# Downloading model.safetensors:  50% 1.38G/2.78G [00:30<00:59, 23.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.36G/10.3G [00:28<07:37, 19.5MB/s]
#
# Downloading model.safetensors:  50% 1.39G/2.78G [00:30<00:48, 28.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.37G/10.3G [00:28<06:02, 24.5MB/s]
#
# Downloading model.safetensors:  51% 1.41G/2.78G [00:30<00:38, 35.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 1.38G/10.3G [00:28<05:11, 28.5MB/s]
#
# Downloading model.safetensors:  51% 1.42G/2.78G [00:30<00:32, 42.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.39G/10.3G [00:28<04:23, 33.7MB/s]
#
# Downloading model.safetensors:  51% 1.43G/2.78G [00:31<00:29, 45.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.41G/10.3G [00:28<03:37, 40.8MB/s]
#
# Downloading model.safetensors:  52% 1.44G/2.78G [00:31<00:37, 36.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.42G/10.3G [00:29<04:00, 36.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.43G/10.3G [00:29<04:10, 35.3MB/s]
#
# Downloading model.safetensors:  52% 1.45G/2.78G [00:32<00:44, 29.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.44G/10.3G [00:29<04:07, 35.6MB/s]
#
# Downloading model.safetensors:  52% 1.46G/2.78G [00:32<00:49, 26.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.45G/10.3G [00:30<04:25, 33.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.46G/10.3G [00:30<03:33, 41.2MB/s]
#
# Downloading model.safetensors:  53% 1.48G/2.78G [00:32<00:30, 42.2MB/s]
#
# Downloading model.safetensors:  54% 1.49G/2.78G [00:32<00:29, 43.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.48G/10.3G [00:30<02:44, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 1.49G/10.3G [00:30<02:35, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.50G/10.3G [00:30<02:24, 60.8MB/s]
#
# Downloading model.safetensors:  54% 1.50G/2.78G [00:33<00:32, 38.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.51G/10.3G [00:31<02:19, 63.0MB/s]
#
# Downloading model.safetensors:  54% 1.51G/2.78G [00:33<00:29, 43.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.52G/10.3G [00:31<02:28, 59.0MB/s]
#
# Downloading model.safetensors:  55% 1.52G/2.78G [00:33<00:27, 45.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.53G/10.3G [00:31<02:26, 59.7MB/s]
#
# Downloading model.safetensors:  55% 1.53G/2.78G [00:33<00:27, 45.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.54G/10.3G [00:31<02:24, 60.3MB/s]
#
# Downloading model.safetensors:  55% 1.54G/2.78G [00:34<00:25, 49.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.55G/10.3G [00:31<02:27, 59.3MB/s]
#
# Downloading model.safetensors:  56% 1.55G/2.78G [00:34<00:24, 51.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.56G/10.3G [00:32<02:29, 58.4MB/s]
#
# Downloading model.safetensors:  56% 1.56G/2.78G [00:34<00:25, 47.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.57G/10.3G [00:33<06:23, 22.7MB/s]
#
# Downloading model.safetensors:  57% 1.57G/2.78G [00:35<00:50, 24.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 1.58G/10.3G [00:33<04:57, 29.2MB/s]
#
# Downloading model.safetensors:  57% 1.59G/2.78G [00:35<00:35, 33.4MB/s]
#
# Downloading model.safetensors:  58% 1.60G/2.78G [00:35<00:29, 39.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.59G/10.3G [00:33<04:59, 29.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.61G/10.3G [00:33<03:15, 44.3MB/s]
#
# Downloading model.safetensors:  58% 1.61G/2.78G [00:36<00:31, 37.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.63G/10.3G [00:33<03:01, 47.6MB/s]
#
# Downloading model.safetensors:  58% 1.63G/2.78G [00:36<00:30, 38.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.64G/10.3G [00:34<03:01, 47.7MB/s]
#
# Downloading model.safetensors:  59% 1.64G/2.78G [00:36<00:25, 44.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.65G/10.3G [00:34<02:43, 52.6MB/s]
#
# Downloading model.safetensors:  59% 1.65G/2.78G [00:36<00:23, 49.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.66G/10.3G [00:34<02:40, 53.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.67G/10.3G [00:34<02:28, 57.9MB/s]
#
# Downloading model.safetensors:  60% 1.66G/2.78G [00:36<00:22, 48.9MB/s]
#
# Downloading model.safetensors:  60% 1.67G/2.78G [00:37<00:21, 51.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.68G/10.3G [00:34<02:49, 50.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 1.69G/10.3G [00:35<02:36, 54.8MB/s]
#
# Downloading model.safetensors:  60% 1.68G/2.78G [00:37<00:24, 45.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.70G/10.3G [00:35<02:29, 57.4MB/s]
#
# Downloading model.safetensors:  61% 1.69G/2.78G [00:37<00:23, 45.5MB/s]
#
# Downloading model.safetensors:  61% 1.70G/2.78G [00:37<00:23, 45.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.71G/10.3G [00:35<03:21, 42.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.72G/10.3G [00:35<02:47, 51.2MB/s]
#
# Downloading model.safetensors:  62% 1.71G/2.78G [00:38<00:25, 41.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.74G/10.3G [00:35<02:08, 66.5MB/s]
#
# Downloading model.safetensors:  62% 1.72G/2.78G [00:38<00:22, 46.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.75G/10.3G [00:36<02:04, 68.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.76G/10.3G [00:36<02:02, 69.4MB/s]
#
# Downloading model.safetensors:  62% 1.73G/2.78G [00:38<00:23, 44.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.77G/10.3G [00:36<02:23, 59.1MB/s]
#
# Downloading model.safetensors:  63% 1.74G/2.78G [00:38<00:20, 49.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.78G/10.3G [00:36<02:19, 61.1MB/s]
#
# Downloading model.safetensors:  63% 1.75G/2.78G [00:38<00:18, 54.4MB/s]
#
# Downloading model.safetensors:  63% 1.76G/2.78G [00:39<00:20, 50.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 1.79G/10.3G [00:36<02:41, 52.5MB/s]
#
# Downloading model.safetensors:  64% 1.77G/2.78G [00:39<00:19, 51.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.80G/10.3G [00:37<02:56, 47.9MB/s]
#
# Downloading model.safetensors:  64% 1.78G/2.78G [00:39<00:19, 50.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.81G/10.3G [00:37<02:39, 53.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.82G/10.3G [00:37<02:32, 55.5MB/s]
#
# Downloading model.safetensors:  65% 1.79G/2.78G [00:39<00:20, 48.2MB/s]
#
# Downloading model.safetensors:  65% 1.80G/2.78G [00:39<00:18, 51.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.84G/10.3G [00:37<02:53, 48.7MB/s]
#
# Downloading model.safetensors:  65% 1.81G/2.78G [00:40<00:17, 56.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.85G/10.3G [00:37<02:41, 52.0MB/s]
#
# Downloading model.safetensors:  66% 1.82G/2.78G [00:40<00:17, 55.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.86G/10.3G [00:38<02:32, 55.1MB/s]
#
# Downloading model.safetensors:  66% 1.84G/2.78G [00:40<00:16, 57.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.87G/10.3G [00:38<02:30, 55.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.88G/10.3G [00:38<02:14, 62.2MB/s]
#
# Downloading model.safetensors:  66% 1.85G/2.78G [00:40<00:16, 56.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.89G/10.3G [00:38<02:26, 57.3MB/s]
#
# Downloading model.safetensors:  67% 1.86G/2.78G [00:40<00:17, 52.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 1.90G/10.3G [00:38<02:25, 57.3MB/s]
#
# Downloading model.safetensors:  67% 1.87G/2.78G [00:41<00:17, 53.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.91G/10.3G [00:39<02:51, 48.9MB/s]
#
# Downloading model.safetensors:  68% 1.88G/2.78G [00:41<00:18, 48.2MB/s]
#
# Downloading model.safetensors:  68% 1.89G/2.78G [00:41<00:17, 51.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.92G/10.3G [00:39<03:23, 41.0MB/s]
#
# Downloading model.safetensors:  68% 1.90G/2.78G [00:41<00:17, 49.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.93G/10.3G [00:39<03:27, 40.2MB/s]
#
# Downloading model.safetensors:  69% 1.91G/2.78G [00:42<00:19, 43.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.94G/10.3G [00:40<04:02, 34.4MB/s]
#
# Downloading model.safetensors:  69% 1.92G/2.78G [00:42<00:22, 38.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.95G/10.3G [00:40<03:58, 34.9MB/s]
#
# Downloading model.safetensors:  69% 1.93G/2.78G [00:42<00:25, 33.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.96G/10.3G [00:40<03:31, 39.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.97G/10.3G [00:40<03:13, 42.9MB/s]
#
# Downloading model.safetensors:  70% 1.94G/2.78G [00:43<00:26, 31.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.98G/10.3G [00:40<02:55, 47.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 1.99G/10.3G [00:41<02:51, 48.2MB/s]
#
# Downloading model.safetensors:  70% 1.95G/2.78G [00:43<00:24, 33.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.00G/10.3G [00:41<02:52, 47.9MB/s]
#
# Downloading model.safetensors:  71% 1.96G/2.78G [00:43<00:22, 36.6MB/s]
#
# Downloading model.safetensors:  71% 1.97G/2.78G [00:43<00:19, 40.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.01G/10.3G [00:41<03:01, 45.6MB/s]
#
# Downloading model.safetensors:  71% 1.98G/2.78G [00:44<00:18, 41.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.02G/10.3G [00:41<02:59, 46.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.03G/10.3G [00:42<02:48, 48.7MB/s]
#
# Downloading model.safetensors:  72% 1.99G/2.78G [00:44<00:18, 42.6MB/s]
#
# Downloading model.safetensors:  72% 2.00G/2.78G [00:44<00:16, 47.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.04G/10.3G [00:42<02:54, 47.2MB/s]
#
# Downloading model.safetensors:  72% 2.01G/2.78G [00:44<00:15, 49.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.06G/10.3G [00:42<02:58, 46.1MB/s]
#
# Downloading model.safetensors:  73% 2.02G/2.78G [00:44<00:15, 49.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.07G/10.3G [00:42<02:44, 49.9MB/s]
#
# Downloading model.safetensors:  73% 2.03G/2.78G [00:45<00:14, 52.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.08G/10.3G [00:42<02:29, 55.0MB/s]
#
# Downloading model.safetensors:  74% 2.04G/2.78G [00:45<00:13, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.09G/10.3G [00:43<02:26, 55.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 2.10G/10.3G [00:43<02:19, 58.7MB/s]
#
# Downloading model.safetensors:  74% 2.06G/2.78G [00:45<00:13, 53.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.11G/10.3G [00:43<02:13, 61.0MB/s]
#
# Downloading model.safetensors:  74% 2.07G/2.78G [00:45<00:14, 50.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.12G/10.3G [00:43<02:09, 63.0MB/s]
#
# Downloading model.safetensors:  75% 2.08G/2.78G [00:45<00:12, 54.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.13G/10.3G [00:43<02:11, 61.7MB/s]
#
# Downloading model.safetensors:  75% 2.09G/2.78G [00:46<00:13, 51.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.14G/10.3G [00:43<02:06, 64.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.15G/10.3G [00:43<02:04, 65.0MB/s]
#
# Downloading model.safetensors:  75% 2.10G/2.78G [00:46<00:12, 53.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.16G/10.3G [00:44<02:07, 63.5MB/s]
#
# Downloading model.safetensors:  76% 2.11G/2.78G [00:46<00:12, 54.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.17G/10.3G [00:44<02:00, 67.0MB/s]
#
# Downloading model.safetensors:  76% 2.12G/2.78G [00:46<00:12, 53.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.18G/10.3G [00:44<02:09, 62.4MB/s]
#
# Downloading model.safetensors:  77% 2.13G/2.78G [00:46<00:11, 54.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.19G/10.3G [00:44<02:03, 65.5MB/s]
#
# Downloading model.safetensors:  77% 2.14G/2.78G [00:46<00:10, 58.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 2.20G/10.3G [00:44<02:02, 65.7MB/s]
#
# Downloading model.safetensors:  77% 2.15G/2.78G [00:47<00:10, 62.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.21G/10.3G [00:44<02:04, 64.5MB/s]
#
# Downloading model.safetensors:  78% 2.16G/2.78G [00:47<00:10, 58.9MB/s]
#
# Downloading model.safetensors:  78% 2.17G/2.78G [00:47<00:09, 61.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.22G/10.3G [00:45<02:29, 54.0MB/s]
#
# Downloading model.safetensors:  78% 2.18G/2.78G [00:47<00:10, 58.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.23G/10.3G [00:45<02:29, 53.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.24G/10.3G [00:45<02:23, 56.0MB/s]
#
# Downloading model.safetensors:  79% 2.19G/2.78G [00:47<00:10, 54.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.25G/10.3G [00:45<02:17, 58.5MB/s]
#
# Downloading model.safetensors:  79% 2.20G/2.78G [00:48<00:09, 58.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.26G/10.3G [00:45<02:15, 59.2MB/s]
#
# Downloading model.safetensors:  80% 2.21G/2.78G [00:48<00:09, 59.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.28G/10.3G [00:46<02:20, 57.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.29G/10.3G [00:46<02:12, 60.1MB/s]
#
# Downloading model.safetensors:  80% 2.22G/2.78G [00:48<00:11, 46.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.30G/10.3G [00:46<02:10, 61.3MB/s]
#
# Downloading model.safetensors:  81% 2.24G/2.78G [00:48<00:09, 55.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 2.31G/10.3G [00:46<02:11, 60.6MB/s]
#
# Downloading model.safetensors:  81% 2.25G/2.78G [00:49<00:08, 59.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.32G/10.3G [00:46<02:07, 62.5MB/s]
#
# Downloading model.safetensors:  82% 2.26G/2.78G [00:49<00:08, 59.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.33G/10.3G [00:46<02:13, 59.3MB/s]
#
# Downloading model.safetensors:  82% 2.28G/2.78G [00:49<00:08, 58.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.34G/10.3G [00:47<02:21, 56.2MB/s]
#
# Downloading model.safetensors:  82% 2.29G/2.78G [00:49<00:09, 52.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.35G/10.3G [00:47<02:16, 57.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.36G/10.3G [00:47<02:17, 57.4MB/s]
#
# Downloading model.safetensors:  83% 2.30G/2.78G [00:49<00:09, 52.6MB/s]
#
# Downloading model.safetensors:  83% 2.31G/2.78G [00:50<00:09, 47.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.37G/10.3G [00:47<03:17, 39.9MB/s]
#
# Downloading model.safetensors:  83% 2.32G/2.78G [00:50<00:09, 49.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.38G/10.3G [00:48<02:59, 43.9MB/s]
#
# Downloading model.safetensors:  84% 2.33G/2.78G [00:50<00:08, 51.0MB/s]
#
# Downloading model.safetensors:  84% 2.34G/2.78G [00:50<00:08, 53.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.39G/10.3G [00:48<02:54, 45.1MB/s]
#
# Downloading model.safetensors:  85% 2.35G/2.78G [00:50<00:07, 56.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.40G/10.3G [00:48<02:37, 50.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 2.41G/10.3G [00:48<02:27, 53.4MB/s]
#
# Downloading model.safetensors:  85% 2.36G/2.78G [00:51<00:07, 54.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.42G/10.3G [00:48<02:34, 50.9MB/s]
#
# Downloading model.safetensors:  85% 2.37G/2.78G [00:51<00:08, 49.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.43G/10.3G [00:49<02:28, 52.7MB/s]
#
# Downloading model.safetensors:  86% 2.38G/2.78G [00:51<00:08, 47.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.44G/10.3G [00:49<02:24, 54.1MB/s]
#
# Downloading model.safetensors:  86% 2.39G/2.78G [00:51<00:07, 51.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.45G/10.3G [00:49<02:20, 55.8MB/s]
#
# Downloading model.safetensors:  86% 2.40G/2.78G [00:51<00:07, 52.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.46G/10.3G [00:49<02:13, 58.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.47G/10.3G [00:49<02:04, 62.8MB/s]
#
# Downloading model.safetensors:  87% 2.41G/2.78G [00:52<00:06, 54.2MB/s]
#
# Downloading model.safetensors:  87% 2.42G/2.78G [00:52<00:06, 57.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.49G/10.3G [00:49<02:09, 60.3MB/s]
#
# Downloading model.safetensors:  88% 2.43G/2.78G [00:52<00:05, 61.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.50G/10.3G [00:50<02:10, 59.7MB/s]
#
# Downloading model.safetensors:  88% 2.44G/2.78G [00:52<00:05, 60.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 2.51G/10.3G [00:50<02:07, 60.9MB/s]
#
# Downloading model.safetensors:  88% 2.45G/2.78G [00:52<00:05, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.52G/10.3G [00:50<02:06, 61.4MB/s]
#
# Downloading model.safetensors:  89% 2.46G/2.78G [00:52<00:05, 55.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.53G/10.3G [00:50<02:25, 53.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.54G/10.3G [00:50<02:14, 57.7MB/s]
#
# Downloading model.safetensors:  89% 2.47G/2.78G [00:53<00:05, 52.9MB/s]
#
# Downloading model.safetensors:  89% 2.49G/2.78G [00:53<00:05, 57.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.55G/10.3G [00:51<02:11, 58.9MB/s]
#
# Downloading model.safetensors:  90% 2.50G/2.78G [00:53<00:04, 56.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.56G/10.3G [00:51<02:22, 54.2MB/s]
#
# Downloading model.safetensors:  90% 2.51G/2.78G [00:53<00:04, 57.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.57G/10.3G [00:51<02:26, 52.7MB/s]
#
# Downloading model.safetensors:  91% 2.52G/2.78G [00:53<00:04, 57.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.58G/10.3G [00:51<02:24, 53.3MB/s]
#
# Downloading model.safetensors:  91% 2.53G/2.78G [00:54<00:04, 58.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.59G/10.3G [00:51<02:19, 55.0MB/s]
#
# Downloading model.safetensors:  91% 2.54G/2.78G [00:54<00:04, 58.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.60G/10.3G [00:52<02:17, 55.9MB/s]
#
# Downloading model.safetensors:  92% 2.55G/2.78G [00:54<00:03, 58.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 2.61G/10.3G [00:52<02:11, 58.3MB/s]
#
# Downloading model.safetensors:  92% 2.56G/2.78G [00:54<00:03, 60.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  26% 2.62G/10.3G [00:52<02:05, 60.7MB/s]
#
# Downloading model.safetensors:  92% 2.57G/2.78G [00:54<00:03, 53.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  26% 2.63G/10.3G [00:52<02:06, 60.5MB/s]
#
#
# ...
#
#
# Downloading (…)ch_model.safetensors:  83% 8.56G/10.3G [02:36<00:32, 52.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  83% 8.57G/10.3G [02:36<00:30, 55.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.58G/10.3G [02:36<00:29, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.59G/10.3G [02:36<00:30, 54.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.60G/10.3G [02:37<00:36, 45.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.61G/10.3G [02:37<00:32, 51.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.62G/10.3G [02:37<00:29, 55.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.63G/10.3G [02:37<00:27, 59.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.64G/10.3G [02:37<00:25, 64.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.65G/10.3G [02:38<00:24, 67.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.66G/10.3G [02:38<00:23, 67.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 8.67G/10.3G [02:38<00:23, 67.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.68G/10.3G [02:38<00:24, 64.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.69G/10.3G [02:38<00:24, 63.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.70G/10.3G [02:38<00:24, 65.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.71G/10.3G [02:39<00:27, 56.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.72G/10.3G [02:39<00:33, 45.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.73G/10.3G [02:39<00:32, 47.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.75G/10.3G [02:39<00:34, 43.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.76G/10.3G [02:40<00:30, 49.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.77G/10.3G [02:40<00:28, 53.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 8.78G/10.3G [02:40<00:26, 55.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.79G/10.3G [02:40<00:27, 53.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.80G/10.3G [02:41<00:40, 36.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.81G/10.3G [02:41<00:38, 37.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.82G/10.3G [02:41<00:37, 38.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.83G/10.3G [02:41<00:32, 44.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.84G/10.3G [02:41<00:29, 48.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.85G/10.3G [02:42<00:26, 52.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.86G/10.3G [02:42<00:25, 55.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.87G/10.3G [02:42<00:23, 58.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 8.88G/10.3G [02:42<00:23, 58.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.89G/10.3G [02:42<00:25, 54.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.90G/10.3G [02:43<00:28, 48.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.91G/10.3G [02:43<00:27, 50.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.92G/10.3G [02:43<00:25, 52.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.93G/10.3G [02:43<00:24, 53.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.94G/10.3G [02:43<00:22, 58.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.95G/10.3G [02:43<00:22, 59.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.97G/10.3G [02:44<00:22, 59.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.98G/10.3G [02:44<00:21, 60.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 8.99G/10.3G [02:44<00:20, 63.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.00G/10.3G [02:44<00:19, 66.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.01G/10.3G [02:44<00:18, 67.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.02G/10.3G [02:44<00:18, 69.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.03G/10.3G [02:45<00:18, 66.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.04G/10.3G [02:45<00:18, 66.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.05G/10.3G [02:45<00:21, 58.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.06G/10.3G [02:45<00:20, 57.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.07G/10.3G [02:45<00:23, 51.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 9.08G/10.3G [02:46<00:31, 37.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.09G/10.3G [02:46<00:29, 39.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.10G/10.3G [02:46<00:25, 45.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.11G/10.3G [02:46<00:23, 49.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.12G/10.3G [02:47<00:21, 54.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.13G/10.3G [02:47<00:20, 56.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.14G/10.3G [02:47<00:20, 55.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.15G/10.3G [02:47<00:25, 43.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.16G/10.3G [02:48<00:26, 42.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.18G/10.3G [02:48<00:28, 38.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 9.19G/10.3G [02:48<00:27, 40.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.20G/10.3G [02:48<00:24, 43.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.21G/10.3G [02:48<00:23, 45.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.22G/10.3G [02:49<00:21, 50.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.23G/10.3G [02:49<00:19, 54.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.24G/10.3G [02:49<00:20, 51.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.25G/10.3G [02:49<00:19, 52.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.26G/10.3G [02:49<00:19, 52.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.27G/10.3G [02:50<00:18, 55.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.28G/10.3G [02:50<00:16, 59.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 9.29G/10.3G [02:50<00:16, 59.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.30G/10.3G [02:50<00:15, 60.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.31G/10.3G [02:50<00:14, 64.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.32G/10.3G [02:50<00:13, 67.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.33G/10.3G [02:51<00:13, 68.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.34G/10.3G [02:51<00:15, 61.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.35G/10.3G [02:51<00:14, 62.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.36G/10.3G [02:51<00:14, 62.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.37G/10.3G [02:51<00:13, 65.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.38G/10.3G [02:51<00:14, 60.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 9.40G/10.3G [02:52<00:13, 62.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.41G/10.3G [02:52<00:14, 58.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.42G/10.3G [02:52<00:15, 56.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.43G/10.3G [02:52<00:14, 57.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.44G/10.3G [02:52<00:13, 60.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.45G/10.3G [02:52<00:13, 59.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.46G/10.3G [02:53<00:13, 61.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.47G/10.3G [02:53<00:13, 60.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.48G/10.3G [02:53<00:14, 55.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 9.49G/10.3G [02:53<00:14, 52.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.50G/10.3G [02:53<00:14, 54.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.51G/10.3G [02:54<00:13, 55.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.52G/10.3G [02:54<00:13, 56.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.53G/10.3G [02:54<00:14, 52.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.54G/10.3G [02:54<00:13, 52.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.55G/10.3G [02:54<00:14, 50.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.56G/10.3G [02:55<00:14, 49.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.57G/10.3G [02:55<00:15, 45.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.58G/10.3G [02:55<00:14, 46.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 9.59G/10.3G [02:55<00:13, 48.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.60G/10.3G [02:56<00:13, 48.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.62G/10.3G [02:56<00:14, 43.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.63G/10.3G [02:56<00:13, 46.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.64G/10.3G [02:56<00:13, 47.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.65G/10.3G [02:56<00:13, 47.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.66G/10.3G [02:57<00:12, 50.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.67G/10.3G [02:57<00:11, 52.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.68G/10.3G [02:57<00:12, 49.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.69G/10.3G [02:57<00:10, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 9.70G/10.3G [02:57<00:10, 53.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.71G/10.3G [02:58<00:09, 56.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.72G/10.3G [02:58<00:09, 55.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.73G/10.3G [02:58<00:09, 59.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.74G/10.3G [02:58<00:08, 61.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.75G/10.3G [02:58<00:09, 57.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.76G/10.3G [02:58<00:08, 57.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.77G/10.3G [02:59<00:08, 57.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.78G/10.3G [02:59<00:08, 60.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.79G/10.3G [02:59<00:08, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 9.80G/10.3G [02:59<00:08, 56.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.81G/10.3G [02:59<00:08, 53.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.83G/10.3G [03:00<00:10, 43.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.85G/10.3G [03:00<00:06, 61.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.86G/10.3G [03:00<00:06, 60.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.87G/10.3G [03:00<00:06, 62.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.88G/10.3G [03:01<00:06, 58.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.89G/10.3G [03:01<00:06, 57.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.90G/10.3G [03:01<00:06, 56.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 9.91G/10.3G [03:01<00:06, 55.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.92G/10.3G [03:01<00:06, 53.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.93G/10.3G [03:01<00:06, 55.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.94G/10.3G [03:02<00:05, 58.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.95G/10.3G [03:02<00:05, 61.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.96G/10.3G [03:02<00:05, 53.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.97G/10.3G [03:02<00:05, 53.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.98G/10.3G [03:02<00:05, 53.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 9.99G/10.3G [03:03<00:05, 54.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 10.0G/10.3G [03:03<00:04, 56.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.0G/10.3G [03:03<00:04, 56.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.0G/10.3G [03:03<00:04, 55.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.0G/10.3G [03:03<00:04, 58.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.0G/10.3G [03:04<00:03, 58.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.1G/10.3G [03:04<00:03, 60.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.1G/10.3G [03:04<00:03, 55.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.1G/10.3G [03:04<00:03, 58.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.1G/10.3G [03:04<00:03, 59.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.1G/10.3G [03:04<00:02, 61.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 10.1G/10.3G [03:05<00:02, 59.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.1G/10.3G [03:05<00:02, 53.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.1G/10.3G [03:05<00:02, 49.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.1G/10.3G [03:05<00:02, 53.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:05<00:02, 55.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:06<00:01, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:06<00:01, 60.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:06<00:01, 61.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:06<00:01, 61.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:06<00:01, 56.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 10.2G/10.3G [03:06<00:00, 60.3MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 10.2G/10.3G [03:07<00:00, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 10.2G/10.3G [03:07<00:00, 50.4MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 10.2G/10.3G [03:07<00:00, 55.2MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 10.3G/10.3G [03:07<00:00, 54.9MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 10.3G/10.3G [03:07<00:00, 54.6MB/s]
# Fetching 19 files: 100% 19/19 [03:11<00:00, 10.08s/it]
# 2023-09-17 09:17:49.681523: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-17T09:17:54+0000 [INFO] [cli] Environ for worker 0: set CPU thread count to 2
# 2023-09-17T09:17:54+0000 [INFO] [cli] Prometheus metrics for HTTP BentoServer from "service.py:svc" can be accessed at http://localhost:3000/metrics.
# 2023-09-17T09:17:55+0000 [INFO] [cli] Starting production HTTP BentoServer from "service.py:svc" listening on http://0.0.0.0:3000 (Press CTRL+C to quit)
# 2023-09-17 09:18:11.321310: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-17 09:18:11.342888: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-17 09:18:11.809777: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 7/7 [00:07<00:00,  1.09s/it]
#
# 🚀 Next step: run 'onediffusion build stable_diffusion_xl' to create a Bento for stable_diffusion_xl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4451f2a1e7a2> in <cell line: 1>()
# ----> 1 get_ipython().system('onediffusion start stable-diffusion-xl')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     201       os.close(child_pty)
#     202
# --> 203       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     204   finally:
#     205     epoll.close()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     231   while True:
#     232     try:
# --> 233       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     234       if result is not None:
#     235         return result
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     279   output_available = False
#     280
# --> 281   events = epoll.poll()
#     282   input_events = []
#     283   for _, event in events:
#
# KeyboardInterrupt:

# %%
# !bentoml models list
# Out:
#  Tag                          Module             Size       Creation Time
#  pt-sdxl-stabilityai--stabl…  bentoml.diffusers  13.24 GiB  2023-09-17 09:12:30

# %%
# !curl -X 'POST' \
     'http://0.0.0.0:3000/text2img' \
     -H 'accept: image/jpeg' \
     -H 'Content-Type: application/json' \
     --output output.jpeg \
     -d '''{
     "prompt": "the scene is a picturesque environment with beautiful flowers and trees. In the center, there is a small cat. The cat is shown with its chin being scratched. It is crouched down peacefully. The cat's eyes are filled with excitement and satisfaction as it uses its small paws to hold onto the food, emitting a content purring sound.",
     "negative_prompt": null,
     "height": 1024,
     "width": 1024,
     "num_inference_steps": 50,
     "guidance_scale": 7.5,
     "eta": 0,
     "lora_weights": null
     }'''
# Out:
#   File "<ipython-input-6-cc96ae0f3a32>", line 2
#     "prompt": "the scene is a picturesque environment with beautiful flowers and trees. In the center, there is a small cat. The cat is shown with its chin being scratched. It is crouched down peacefully. The cat's eyes are filled with excitement and satisfaction as it uses its small paws to hold onto the food, emitting a content purring sound.",
#     ^
# IndentationError: unexpected indent
